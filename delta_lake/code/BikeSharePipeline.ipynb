# %% [markdown]
# This is our master bike sharing pipeline. It executes notebooks using the notebook workflow capabilties of databricks.
#
# This notebook will:
#  - Execute
#  - Execute
#  - Execute

# %% [markdown]
# Load data from source to bronze

# %%
dbutils.notebook.run("01b_BatchSourceToBronze", 0)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Load data from bronze to silver

# %%
dbutils.notebook.run("02b_BatchBronzeToSilver", 0)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Load data from silver to gold

# %%
dbutils.notebook.run("02b_BatchSilver", 0)
