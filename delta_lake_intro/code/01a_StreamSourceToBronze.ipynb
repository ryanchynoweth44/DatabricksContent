# %% [markdown]
# We will simulate a streaming data source by loading a dataframe and writing rows to our source file system using a sleep command.
#
# We will be using a sample IoT dataset.

# %%
from pyspark.sql.functions import col
from pyspark.sql.functions import monotonically_increasing_id
from time import sleep

df = (spark.read.format('json').load("/databricks-datasets/iot/iot_devices.json")
  .orderBy(col("timestamp"))
  .withColumn("id", monotonically_increasing_id()) )

# %%
display(df)

# %%
## for out simulation we will save our data frame to a table and collect batchs to write on a cadence
try:
  df = spark.sql("SELECT * FROM stream_data")
  print("Table Exists. Loaded Data.")
except:
  df.write.saveAsTable("stream_data")
  print("Table Created.")

# %%
current = 0
num_rows = df.count()
batch_size = 4000
frequency = 5
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
while current < num_rows:
  stream_df = spark.sql("select * from stream_data where id >= {} and id < {}".format(current, current+batch_size))
  stream_df.write.format("delta").mode("append").save("/mnt/delta/bronze/iot/stream_data")
  print("Streamed IDs between: {} and {}".format(current, current+batch_size-1))
  current = current+batch_size

  sleep(frequency)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Streamed IDs between: 0 and 3999
# Streamed IDs between: 4000 and 7999
# Streamed IDs between: 8000 and 11999
# Streamed IDs between: 12000 and 15999
# Streamed IDs between: 16000 and 19999
# Streamed IDs between: 20000 and 23999
# Streamed IDs between: 24000 and 27999
# Streamed IDs between: 28000 and 31999
# Streamed IDs between: 32000 and 35999
# Streamed IDs between: 36000 and 39999
# Streamed IDs between: 40000 and 43999
# Streamed IDs between: 44000 and 47999
# Streamed IDs between: 48000 and 51999
# Streamed IDs between: 52000 and 55999
# Streamed IDs between: 56000 and 59999
# Streamed IDs between: 60000 and 63999
# Streamed IDs between: 64000 and 67999
# Streamed IDs between: 68000 and 71999
# Streamed IDs between: 72000 and 75999
# Streamed IDs between: 76000 and 79999
# Streamed IDs between: 80000 and 83999
# Streamed IDs between: 84000 and 87999
# Streamed IDs between: 88000 and 91999
# Streamed IDs between: 92000 and 95999
# Streamed IDs between: 96000 and 99999
# Streamed IDs between: 100000 and 103999
# Streamed IDs between: 104000 and 107999
# Streamed IDs between: 108000 and 111999
# Streamed IDs between: 112000 and 115999
# Streamed IDs between: 116000 and 119999
# Streamed IDs between: 120000 and 123999
# Streamed IDs between: 124000 and 127999
# Streamed IDs between: 128000 and 131999
# Streamed IDs between: 132000 and 135999
# Streamed IDs between: 136000 and 139999
# Streamed IDs between: 140000 and 143999
# Streamed IDs between: 144000 and 147999
# Streamed IDs between: 148000 and 151999
# Streamed IDs between: 152000 and 155999
# Streamed IDs between: 156000 and 159999
# Streamed IDs between: 160000 and 163999
# Streamed IDs between: 164000 and 167999
# Streamed IDs between: 168000 and 171999
# Streamed IDs between: 172000 and 175999
# Streamed IDs between: 176000 and 179999
# Streamed IDs between: 180000 and 183999
# Streamed IDs between: 184000 and 187999
# Streamed IDs between: 188000 and 191999
# Streamed IDs between: 192000 and 195999
# Streamed IDs between: 196000 and 199999
# </div>
